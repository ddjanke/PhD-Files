# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style(style = 'white',rc={'figure.figsize':(3.25,1), 'font.family':"Times New Roman", 'font.size': 10,
                                  'patch.edgecolor': 'darkgrey', 'dpi': 300})

# %%
single_directory = 'Results/'
single = pd.read_csv(directory+'Result_All_bounded.csv',header=None)
single_20 = single.loc[4001:]
single_val_20 = single_20[2].to_frame()
single.head()
# Out:
#           0          1          2          3          4          5   \
# 0  89.375582  89.427740  89.432891  82.652789  83.533795  80.521845
# 1  89.779435  89.395414  89.394731  82.629767  83.282768  80.807609
# 2  89.282386  89.380936  89.374168  82.702556  83.287297  80.848778
# 3  89.996893  89.359137  89.378773  82.710548  83.397036  80.831366
# 4  90.121156  89.456585  89.444928  82.600978  83.664372  80.271584
#
#           6             7             8          9          10         11  \
# 0  98.553526  1.079457e-02  2.625728e-03  89.313451  89.554152  89.558067
# 1  98.572531  1.026729e-02  3.095131e-03  90.214352  89.687841  89.690265
# 2  98.566324  1.208269e-02  2.822385e-03  89.313451  89.292553  89.283884
# 3  98.567229  9.233074e-11  1.841462e-11  89.996893  89.359137  89.378773
# 4  98.534395  1.398795e-02  5.169406e-03  89.903697  89.397042  89.388815
#
#           12         13         14         15
# 0  81.316750  84.934747  78.399979  98.353818
# ...

# %%
parallel_directory = 'ParallelResults/'
parallel_20 = pd.read_csv(parallel_directory+'Result_Parallel4.csv',header=None)
parallel_val_20 = parallel_20[2]
orig_acc = parallel_val_20 .loc[0]
parallel_val_20_train = parallel_val_20.loc[1:1001].to_frame()
parallel_val_20_test = parallel_val_20.loc[1001:2001].to_frame()
parallel_20.head()
# Out:
#            0          1          2          3          4          5          6
# 0  90.525008  90.631675  90.640804  84.887270  83.631448  73.397758  98.690246
# 1  88.692140  89.273476  89.269120  80.684307  86.056150  59.072127  98.374381
# 2  89.624107  89.682504  89.685791  83.569031  85.415657  62.477181  98.579164
# 3  90.462877  90.314529  90.324092  83.727369  83.077057  73.632391  98.720190
# 4  90.928860  90.385269  90.389719  83.437847  85.482193  72.588135  98.508337

# %%
single_val_20['test'] = 'Individual w/ Noise'
parallel_val_20_train['test'] = 'Parallel Trained'
parallel_val_20_test['test'] = 'Parallel Untrained'
all_acc = pd.concat([single_val_20, parallel_val_20_train,
                     parallel_val_20_test], axis = 0, ignore_index = True)
all_acc.columns = ['Accuracy', 'Test']

# %%
plt.figure(figsize = (5,2))
box1 = sns.boxenplot(x = 'Test',y = 'Accuracy', data = all_acc,
                     palette = ["darkgrey", "lightgrey", "grey"])
plt.ylabel('Accuracy (%)')
fig = box1.get_figure()
fig.savefig('ParallelTrain.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(res[3])
plt.plot(res[12])
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show();

# %%
plt.plot(res[4])
plt.plot(res[13])
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show();

# %%
plt.plot(res[5])
plt.plot(res[14])
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show();

# %%
plt.plot(res[6])
plt.plot(res[15])
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show();

# %%
directory = '/home/djanke3/Documents/Spyder/ParallelResults/'
res0 = np.loadtxt(directory+'Result_Parallel0.csv',delimiter=',')
res1 = np.loadtxt(directory+'Result_Parallel1.csv',delimiter=',')
res2 = np.loadtxt(directory+'Result_Parallel2.csv',delimiter=',')
res3 = np.loadtxt(directory+'Result_Parallel3.csv',delimiter=',')
#res40 = np.loadtxt(directory+'Result_Parallel40.csv',delimiter=',')
#res41 = np.loadtxt(directory+'Result_Parallel41.csv',delimiter=',')
#res4 = np.savetxt(directory+'Result_Parallel4.csv',np.vstack((res40,res41)),delimiter=',')
res4 = np.loadtxt(directory+'Result_Parallel4.csv',delimiter=',')

#res = res[10000:].reset_index()

#res.head()

# %%
audio_set = 0
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 1
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 2
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 3
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 4
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 5
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 6
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
directory = '/home/djanke3/Documents/Spyder/ParallelResultsLarge/'
res0 = np.loadtxt(directory+'Result_ParallelLarge0.csv',delimiter=',')
res1 = np.loadtxt(directory+'Result_ParallelLarge1.csv',delimiter=',')
res2 = np.loadtxt(directory+'Result_ParallelLarge2.csv',delimiter=',')
res3 = np.loadtxt(directory+'Result_ParallelLarge3.csv',delimiter=',')
#res40 = np.loadtxt(directory+'Result_Parallel40.csv',delimiter=',')
#res41 = np.loadtxt(directory+'Result_Parallel41.csv',delimiter=',')
#res4 = np.savetxt(directory+'Result_Parallel4.csv',np.vstack((res40,res41)),delimiter=',')
res4 = np.loadtxt(directory+'Result_ParallelLarge4.csv',delimiter=',')

#res = res[10000:].reset_index()

#res.head()

# %%
audio_set = 0
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 1
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 2
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 3
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 4
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 5
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 6
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
directory = '/home/djanke3/Documents/Spyder/ParallelDropResults/'
#res00 = np.loadtxt(directory+'Result_Parallel00.csv',delimiter=',')
#res01 = np.loadtxt(directory+'Result_Parallel01.csv',delimiter=',')
#res0 = np.savetxt(directory+'Result_Parallel0.csv',np.vstack((res00,res01)),delimiter=',')
res0 = np.loadtxt(directory+'Result_Parallel0.csv',delimiter=',')
res10 = np.loadtxt(directory+'Result_Parallel10.csv',delimiter=',')
res11 = np.loadtxt(directory+'Result_Parallel11.csv',delimiter=',')
res1 = np.savetxt(directory+'Result_Parallel1.csv',np.vstack((res10,res11)),delimiter=',')
res1 = np.loadtxt(directory+'Result_Parallel1.csv',delimiter=',')
res2 = np.loadtxt(directory+'Result_Parallel2.csv',delimiter=',')
res3 = np.loadtxt(directory+'Result_Parallel3.csv',delimiter=',')
res4 = np.loadtxt(directory+'Result_Parallel4.csv',delimiter=',')

#res = res[10000:].reset_index()

#res.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-7203e20d7a18> in <module>
#       1 directory = '/home/djanke3/Documents/Spyder/ParallelDropResults/'
# ----> 2 res00 = np.loadtxt(directory+'Result_Parallel00.csv',delimiter=',')
#       3 res01 = np.loadtxt(directory+'Result_Parallel01.csv',delimiter=',')
#       4 res0 = np.savetxt(directory+'Result_Parallel0.csv',np.vstack((res00,res01)),delimiter=',')
#       5 res0 = np.loadtxt(directory+'Result_Parallel0.csv',delimiter=',')
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
# ...

# %%
audio_set = 6
result_parallel00 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel01 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))
plt.plot(result_parallel00)
plt.plot(result_parallel01)
for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(50,100)
plt.show()

# %%
audio_set = 0

result_parallel0 = np.hstack((res0[:1000,audio_set],res1[:1000,audio_set],res2[:1000,audio_set],
                              res3[:1000,audio_set],res4[:1000,audio_set]))
result_parallel1 = np.hstack((res0[1000:,audio_set],res1[1000:,audio_set],res2[1000:,audio_set],
                              res3[1000:,audio_set],res4[1000:,audio_set]))

plt.plot(res[audio_set],label='Individual w/ Noise',marker = '.',linestyle = '')
plt.plot(result_parallel0,label='Parallel Trained',marker = '.',linestyle = '')
plt.plot(result_parallel1,label='Untrained',marker = '.',linestyle = '')

for x in [1000,2000,3000,4000]:
    plt.axvline(x=x,color='k')
plt.ylim(60,100)
plt.legend()
plt.show()
